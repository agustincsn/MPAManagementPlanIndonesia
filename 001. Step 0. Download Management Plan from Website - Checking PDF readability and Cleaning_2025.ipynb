# %%
#downloaded pdf file on 30 June 2023

#to download all pdf file in the government websites url = "https://kkp.go.id/djprl/kkhl/page/2107-sk-penetapan"
#where the management plan of MPAs in Indonesia are uploaded and available publicly
 

#!/usr/bin/env python
# coding: utf-8

# In[4]:


import os #provides a way to use operating system-dependent functionality, such as working with files and directories.

#This defines a function named extract_url_pdf that takes two arguments: input_url (the URL from which to extract PDF links) and folder_path (the path where the downloaded PDFs and Excel file will be stored). The os.getcwd() function provides the current working directory as a default value for folder_path if it's not provided when the function is called
def extract_url_pdf(input_url,folder_path=os.getcwd()):
    
    import os  
    import requests #module to allow the script to send HTTP requests
    from urllib.parse import urljoin #joiing URLs
    from bs4 import BeautifulSoup #a library for parsing HTML ad XML documents
    import pandas as pd #library for data manipulation and analysis
    import datetime #a module for working with dates and times
    
    url = "https://kkp.go.id/djprl/kkhl/page/2107-sk-penetapan" #the URL that will be scrapted for PDF links

    #If there is no such folder, the script will create one automatically
    #where the downloaded PDFs and excel file will be stored and if the specified folder does not exist, it's created using os.mkdir().
    folder_location = "YourDirectoryPath/Desktop/Analysis_ch1/Automated_MPAMP" 
    if not os.path.exists(folder_location):os.mkdir(folder_location)

    response = requests.get(url)
    soup= BeautifulSoup(response.text, "html.parser") #extract links and other information from the webpage

    #These lines initialize empty lists for storing the text, href attributes, and filenames of the PDF links. counter is used to keep track of the number of files extracted.
    link_text=list()
    link_href=list()
    link_file=list()
    counter=0

    #This starts a loop that iterates over all the <a> elements with an href attribute ending in .pdf in the parsed HTML.
    for link in soup.select("a[href$='.pdf']"):
        #Name the pdf files using the last portion of each link which are unique in this case
        
        #For each PDF link, this code constructs a local filename using the last part of the link's URL, then opens that file and writes the content of the PDF obtained by sending a GET request to the combined URL using requests.get(). The urljoin() function ensures the proper combination of base URL and relative link.
        filename = os.path.join(folder_location,link['href'].split('/')[-1])
        with open(filename, 'wb') as f:
            f.write(requests.get(urljoin(url,link['href'])).content)
            
        #These lines collect information about the extracted link: the text displayed for the link, the full href attribute, and the filename. The counter is incremented, and a message is printed indicating the number and filename of the extracted file.
        link_text.append(str(link.text))
        link_href.append(link['href'])
        link_file.append(link['href'].split('/')[-1])
        counter+=1
        print(counter, "-Files Extracted from URL named ",link['href'].split('/')[-1])
        
    #Here, a dictionary table_dict is created using the collected link information, and then a pandas DataFrame df is created from this dictionary. The DataFrame will hold the extracted data.
    table_dict={"Text":link_text,"Url_Link":link_href,"File Name":link_file}
    df=pd.DataFrame(table_dict)
    
    #This gets the current date and time as a timestamp using the datetime module.
    time_stamp = datetime.datetime.now().strftime('%Y-%m-%d %H-%M-%S')
    
    print("Creating an Excel file with Name of FIle, Url Link and Link Text...")
    
    #This constructs the filename for the Excel output file using the timestamp and folder location.
    new_excel_file=os.path.join(folder_location,"Excel_Output_"+time_stamp+".xlsx")

    #These lines create an Excel writer using pd.ExcelWriter(), then write the DataFrame df to an Excel sheet named "Output". Finally, the changes are saved using writer.save().
    writer = pd.ExcelWriter(new_excel_file, engine='openpyxl')
    df.to_excel(writer,sheet_name="Output")
# 195 -Files Extracted from URL named  3bf94-13-kepmen-kp-2021.pdf
# 196 -Files Extracted from URL named  RPZ%20KKD%20Raja%20Ampat%20(2019).pdf
# 197 -Files Extracted from URL named  c78c5-67-kepmen-kp-2021.pdf
# 198 -Files Extracted from URL named  DF%20KK%20Kolepom%20Papua.pdf
# Creating an Excel file with Name of FIle, Url Link and Link Text...
# All Pdf files downloaded and Excel File Created

# %%
#to check readibility of downloaded pdf/MPA Management plans 

#These lines import the warnings module and then use warnings.filterwarnings() to suppress user warnings specifically from the "PyPDF2" module. This is done to prevent warning messages from being displayed during the execution of the code.
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="PyPDF2")

#importing two modules with operating system functionality and working with PDF files
import os
import PyPDF2

#This block defines a function named check_pdf_readability that takes a file_path as an argument.
def check_pdf_readability(file_path):
    #A try block attempts to open the PDF file in binary ('rb') mode using the provided file_path.
    try:
        with open(file_path, 'rb') as file:
            reader = PyPDF2.PdfFileReader(file) #to read the PDF content
            num_pages = reader.numPages #the number of pages in the PDF
            return num_pages > 0  # If the number of pages is greater than 0, the file is readable
    except Exception:
        return False  # If an error occurs while reading the file, it is not readable

def check_all_pdfs_readability(folder_path):
    #containing filenames of all files in the specified folder that have a lowercase extension of.'pdf'
    pdf_files = [file for file in os.listdir(folder_path) if file.lower().endswith('.pdf')]
    
    #a loop iterates through each PDF file in 'pdf.files'
    for pdf_file in pdf_files:
        file_path = os.path.join(folder_path, pdf_file)
        is_readable = check_pdf_readability(file_path)
        
        if is_readable:
            print(f"The PDF file '{pdf_file}' is readable.")
        else:
            print(f"The PDF file '{pdf_file}' is not readable or an error occurred while reading.")

#directory
folder_path = "YourDirectoryPath/Desktop/Analysis_ch1/Automated_MPAMP"
check_all_pdfs_readability(folder_path)
# Out:
# The PDF file '02c77-48-kepmen-kp-2021.pdf' is not readable or an error occurred while reading.
# The PDF file '05455-2022kepmen-kp36.pdf' is not readable or an error occurred while reading.
# The PDF file '054f7-51-kepmen-kp-2019-ttg-kaw.konservasi-parigi-moutong-poso.....pdf' is not readable or an error occurred while reading.
# The PDF file '05533-kep-29-men-2012-ttg-penetapan-kawasan-konservasi-ujungnegoro.pdf' is not readable or an error occurred while reading.
# The PDF file '05e15-79-kepmen-kp-2020-ttg-teluk-berau-teluk-nusalasi-papua-barat-20-juli-2020.pdf' is not readable or an error occurred while reading.
# The PDF file '0d9fc-kepmen-nomor-94-tahun-2021.pdf' is not readable or an error occurred while reading.
# The PDF file '0f3b6-20-kepmen-kp-2020.pdf' is not readable or an error occurred while reading.
# The PDF file '16b13-kepmen-86-tahun-2020-tentang-kawasan-konservasi-sumut-edit-hm-.pdf' is not readable or an error occurred while reading.
# The PDF file '21ab9-52-kepmen-kp-2019-ttg-kaw.konservasi-morowali-morowali-utara.....pdf' is not readable or an error occurred while reading.
# The PDF file '22%20%20%20%20%20%20KEPMEN-KP%202018.pdf' is not readable or an error occurred while reading.
# The PDF file '26f49-2022kepmen-kp32.pdf' is not readable or an error occurred while reading.
# The PDF file '27224-2022kepmen-kp34.pdf' is not readable or an error occurred while reading.
# The PDF file '2b4da-77-kepmen-kp-2020-ttg-kkpd-tp-aceh-tamiang-edit-hm-3-juni-2020-otentifikasi.pdf' is not readable or an error occurred while reading.
# The PDF file '2f585-2022kepmen-kp17.pdf' is not readable or an error occurred while reading.
# The PDF file '30ad4-23-kepmen-kp-2021.pdf' is not readable or an error occurred while reading.
# The PDF file
kepmen-kp-2020-ttg-kawasan-konservasi-pulau-rao.pdf' is not readable or an error occurred while reading.
# The PDF file 'bb5a0-2022kepmen-kp30.pdf' is not readable or an error occurred while reading.
# The PDF file 'bb637-2022kepmen-kp3.pdf' is not readable or an error occurred while reading.
# The PDF file 'bb7c1-kepmen-94-tahun-2020-tentang-kawasan-konservasi-perairan-belitung-edit-hm-.pdf' is not readable or an error occurred while reading.
# The PDF file 'c117f-kepmen-105-tahun-2021.pdf' is not readable or an error occurred while reading.
# The PDF file 'c78c5-67-kepmen-kp-2021.pdf' is not readable or an error occurred while reading.
# The PDF file 'd0235-kepmen-92-tahun-2020-edit-hm-.pdf' is not readable or an error occurred while reading.
# The PDF file 'd1821-21-kepmen-kp-2018.pdf' is not readable or an error occurred while reading.
# The PDF file 'd1cdb-kiluan.pdf' is readable.
# The PDF file 'dcbaa-76-kepmen-kp-2020-ttg-kkpd-tp-aceh-jaya-edit-hm-10-juni-2020-.pdf' is readable.
# The PDF file 'de1d6-kepmen-87-tahun-2020-tentang-kawasan-konservasi-tapteng-edit-hm-.pdf' is not readable or an error occurred while reading.
# The PDF file 'DF%20BALABALAKANG%20SULBAR.pdf' is readable.
# The PDF file 'DF%20Batang%20Segama.pdf' is readable.
# The PDF file 'DF%20Berhala%20Sumut.pdf' is readable.
# The PDF file 'DF%20Binusan%20Nunukan%20Kaltara.pdf' is readable.
# The PDF file 'DF%20KARANG%20JAHE%20REMBANG.pdf' is readable.
# The PDF file 'DF%20KARANG%20JERUK%20TEGAL.pdf' is readable.
# The PDF file 'DF%20KBT.pdf' is readable.
# The PDF file 'DF%20KK%20Babar.pdf' is readable.
# The PDF file 'DF%20KK%20Bantul%20DIY.pdf' is readable.
# The PDF file 'DF%20KK%20Bintan%20Kepri.pdf' is readable.
# The PDF file 'DF%20KK%20Buleleng%20Bali.pdf' is readable.
# The PDF file 'DF%20KK%20Karangasem%20Bali.pdf' is readable.
# The PDF file 'DF%20KK%20Kolepom%20Papua.pdf' is readable.
# The PDF file 'DF%20KK%20Pangandaran%20Jabar.pdf' is readable.
# The PDF file 'DF%20KK%20Perlang%20Ketugar%20Babel.pdf' is readable.
# The PDF file 'DF%20KK%20Pulau%20Panjang.pdf' is readable.
# The PDF file 'DF%20KK%20Teluk%20Gorontalo.pdf' is readable.
# The PDF file 'DF%20KK%20Tuing%20Babel.pdf' is readable.
# The PDF file 'DF%20KK%20Way%20Kambas.pdf' is readable.
# The PDF file 'DF%20Lipan%20Rakit.pdf' is readable.
# The PDF file 'DF%20Liukang%20Tangaya.pdf' is readable.
# The PDF file 'DF%20Liukang%20Tupabbiring.pdf' is readable.
# The PDF file 'DF%20Mahakam.pdf' is readable.
# The PDF file 'DF%20Ngambur.pdf' is readable.
# The PDF file 'DF%20PULAU%20PANJANG%20JEPARA.pdf' is readable.
# The PDF file 'Dokumen%20Final%20Anambas.pdf' is readable.
# The PDF file 'Dokumen%20Final%20Aru.pdf' is readable.
# The PDF file 'Dokumen%20Final%20Gili%20Matra.pdf' is readable.
# The PDF file 'Dokumen%20Final%20Kapoposang.pdf' is readable.
# The PDF file 'Dokumen%20Final%20Laut%20Banda.pdf' is readable.
# The PDF file 'Dokumen%20Final%20Padaido.pdf' is readable.
# The PDF file 'Dokumen%20Final%20Pieh.pdf' is readable.
# The PDF file 'Dokumen%20Final%20Raja%20Ampat.pdf' is readable.
# The PDF file 'Dokumen%20Final%20Waigeo.pdf' is readable.
# The PDF file 'Dokumen%20RPZ%20KKD%20Pulau%20Weh.pdf' is readable.
# The PDF file 'e4a95-50-kepmen-kp-2019-ttg-kaw.konservasi-donggala-buol.....pdf' is not readable or an error occurred while reading.
# The PDF file 'e63e8-78-kepmen-kp-2020-oke.pdf' is not readable or an error occurred while reading.
# The PDF file 'KEPMENKP%202009%2063%20Aru.pdf' is readable.
# The PDF file 'KEPMENKP%202014%2038%20RPZ%20Pieh.pdf' is readable.
# The PDF file 'KEPMENKP%202014%205%20Sawu.pdf' is readable.
# The PDF file 'KEPMENKP%202014%2053%20RPZ%20Anambas.pdf' is readable.
# The PDF file 'KEPMENKP%202014%2057%20RPZ%20Gili%20Matra.pdf' is readable.
# The PDF file 'KEPMENKP%202014%2058%20RPZ%20Laut%20Banda.pdf' is readable.
# The PDF file 'KEPMENKP%202014%2059%20RPZ%20Kapoposang.pdf' is readable.
# The PDF file 'KEPMENKP%202014%206%20RPZ%20Laut%20Sawu.pdf' is readable.
# The PDF file 'KEPMENKP%202014%2060%20RPZ%20Waigeo%20Sebelah%20Barat.pdf' is readable.
# The PDF file 'KEPMENKP%202014%2062%20RPZ%20Padaido.pdf' is readable.
# The PDF file 'KEPMENKP%202014%2063%20RPZ%20Raja%20Ampat.pdf' is readable.
# The PDF file 'KEPMENKP%202014%2064%20RPZ%20Aru%20Tenggara.pdf' is readable.
# The PDF file 'KEPMENKP%202015%2035%20KKPD%20Alor.pdf' is readable.
# The PDF file 'KEPMENKP%202016%205%20KKPD%20Sukabumi.pdf' is readable.
# The PDF file 'KEPMENKP%202016%206%20KKPD%20Maluku%20Tenggara.pdf' is readable.
# The PDF file 'KEPMENKP%202016%2087%20KKPD%20Berau.pdf' is readable.
# The PDF file 'KEPMENKP%202017%2052%20KKPD%20Belitung%20Timur.pdf' is readable.
# The PDF file 'KEPMENKP%202017%2053%20KKPD%20Jeen%20Womom%20Tambrauw.pdf' is readable.
# The PDF file 'KEPMENKP%202017%2054%20KKPD%20Sawo%20Lahewa%20(Sumut).pdf' is readable.
# The PDF file 'KEPMENKP%202019%2057%20KKD%20Tatoareng%20(Sulut).pdf' is readable.
# The PDF file 'KEPMENKP%202020%20102%20KKD%20Kepulauan%20Widi%20(Malut).pdf' is readable.
# The PDF file 'KEPMENKP%202020%20103%20KKD%20Kepulaun%20Guraici%20(Malut).pdf' is readable.
# The PDF file 'KEPMENKP%202020%20104%20KKD%20Makian%20Moti%20(Malut).pdf' is readable.
# The PDF file 'KEPMENKP%202020%2022%20KKPD%20Teluk%20Cempi%20(NTB).pdf' is readable.
# The PDF file 'KEPMENKP%202022%2047%20KK%20Kep%20Balabalakang%20(Sulbar).pdf' is readable.
# The PDF file 'KEPMENKP%202022%2048%20KK%20Pulau%20Berhala%20(Sumut).pdf' is readable.
# The PDF file 'KEPMENKP%202022%2049%20KK%20Mahakam.pdf' is readable.
# The PDF file 'KEPMENKP%202022%2068%20KK%20Kepulauan%20Babar%20(Maluku).pdf' is readable.
# The PDF file 'RPZ%20Aceh%20Barat%20Daya.pdf' is readable.
# The PDF file 'RPZ%20Aceh%20Besar.pdf' is readable.
# The PDF file 'RPZ%20Aceh%20Jaya.pdf' is readable.
# The PDF file 'RPZ%20Aceh%20Selatan.pdf' is readable.
# The PDF file 'RPZ%20Aceh%20Tamiang.pdf' is readable.
# The PDF file 'RPZ%20Angsana%20Kalsel.pdf' is readable.
# The PDF file 'RPZ%20Ay%20Rhun.pdf' is readable.
# The PDF file 'RPZ%20Banggai%20Dalaka.pdf' is readable.
# The PDF file 'RPZ%20Belitung%20(Babel).pdf' is readable.
# The PDF file 'RPZ%20Bontang.pdf' is readable.
# The PDF file 'RPZ%20Buano.pdf' is readable.
# The PDF file 'RPZ%20Doboto%20(Sulteng).pdf' is readable.
# The PDF file 'RPZ%20Flotim%20NTT.pdf' is readable.
# The PDF file 'RPZ%20Gili%20Banta%20(NTB).pdf' is readable.
# The PDF file 'RPZ%20Gili%20Ketapang.pdf' is readable.
# The PDF file 'RPZ%20Gita%20Nada%20(NTB).pdf' is readable.
# The PDF file 'RPZ%20Guraici%20(Malut).pdf' is readable.
# The PDF file 'RPZ%20Jeen%20Womom%20(Papua%20Barat).pdf' is readable.
# The PDF file 'RPZ%20Kaimana%20(Pabar).pdf' is readable.
# The PDF file 'RPZ%20Kayong%20Utara.pdf' is readable.
# The PDF file 'RPZ%20Kendawangan.pdf' is readable.
# The PDF file 'RPZ%20Kiluan%20(Lampung).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Kep%20Derawan%20(Kaltim).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Nusa%20Penida%20(2017).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Pulau%20Kei%20Kecil%20(Maluku).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Pulau%20Koon%20(Maluku).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Pulau-Pulau%20Batu%20(Sumut).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Raja%20Ampat%20(2019).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Sawo%20Lahewa%20(Sumut).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Selat%20Bunga%20Laut%20(Sumbar).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Tatoareng%20(Sulut).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Ujungnegoro%20(Jateng).pdf' is readable.
# The PDF file 'RPZ%20KKM%20HMAS%20Perth%20(Banten).pdf' is readable.
# The PDF file 'RPZ%20Kubu%20Raya.pdf' is readable.
# The PDF file 'RPZ%20Lease.pdf' is readable.
# The PDF file 'RPZ%20Lembata%20NTT.pdf' is readable.
# The PDF file 'RPZ%20Liang%20dan%20Ngali%20(NTB).pdf' is readable.
# The PDF file 'RPZ%20Makian-Moti%20(Malut).pdf' is readable.
# The PDF file 'RPZ%20Mare%20(Malut).pdf' is readable.
# The PDF file 'RPZ%20Momparang%20(Babel).pdf' is readable.
# The PDF file 'RPZ%20Moramo%20Wawonii.pdf' is readable.
# The PDF file 'RPZ%20Morowali.pdf' is readable.
# The PDF file 'RPZ%20Paloh.pdf' is readable.
# The PDF file 'RPZ%20Pangumbahan%20(Jabar).pdf' is readable.
# The PDF file 'RPZ%20Parigi%20Muotong.pdf' is readable.
# The PDF file 'RPZ%20Pisisi%20(Aceh).pdf' is readable.
# The PDF file 'RPZ%20Pulau%20Randayan%20Bengkayang.pdf' is readable.
# The PDF file 'RPZ%20Rao-Tanjung%20Dehegila%20(Malut).pdf' is readable.
# The PDF file 'RPZ%20Selat%20Pantar%20(NTT).pdf' is readable.
# The PDF file 'RPZ%20Senggora%20-%20Kalteng.pdf' is readable.
# The PDF file 'RPZ%20Serutbar.pdf' is readable.
# The PDF file 'RPZ%20Sikka%20NTT.pdf' is readable.
# The PDF file 'RPZ%20Sula.pdf' is readable.
# The PDF file 'RPZ%20Sulat%20dan%20Lawang%20(NTB).pdf' is readable.
# The PDF file 'RPZ%20Tapanuli%20Tengah%20(Sumut).pdf' is readable.
# The PDF file 'RPZ%20Teluk%20Berau%20(Pabar).pdf' is readable.
# The PDF file 'RPZ%20Teluk%20Cempi%20(NTB).pdf' is readable.
# The PDF file 'RPZ%20Widi%20(Malut).pdf' is readable.
# The PDF file 'RZ%20KK%20Tanjung%20Palas%20Timur%20Kaltara.pdf' is readable.

# %%
#or we can also try the code below, with additional information about the total number of 
#PDF files, the number of readable PDF files, and the number of non-readable PDF files.

import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="PyPDF2")

import os
import PyPDF2

def check_pdf_readability(file_path):
    try:
        with open(file_path, 'rb') as file:
            reader = PyPDF2.PdfFileReader(file)
            num_pages = reader.numPages
            return num_pages > 0  # If the number of pages is greater than 0, the file is readable
    except Exception:
        return False  # If an error occurs while reading the file, it is not readable

def check_all_pdfs_readability(folder_path):
    pdf_files = [file for file in os.listdir(folder_path) if file.lower().endswith('.pdf')]
    num_readable = 0
    num_non_readable = 0

    for pdf_file in pdf_files:
        file_path = os.path.join(folder_path, pdf_file)
        is_readable = check_pdf_readability(file_path)
        
        if is_readable:
            num_readable += 1
            print(f"The PDF file '{pdf_file}' is readable.")
        else:
            num_non_readable += 1
            print(f"The PDF file '{pdf_file}' is not readable or an error occurred while reading.")

    print(f"Total PDF files: {len(pdf_files)}")
    print(f"Readable PDF files: {num_readable}")
    print(f"Non-readable PDF files: {num_non_readable}")

# Example usage:
folder_path = "YourDirectoryPath/Desktop/Analysis_ch1/Automated_MPAMP"
check_all_pdfs_readability(folder_path)
# Out:
# The PDF file '02c77-48-kepmen-kp-2021.pdf' is not readable or an error occurred while reading.
# The PDF file '05455-2022kepmen-kp36.pdf' is not readable or an error occurred while reading.
# The PDF file '054f7-51-kepmen-kp-2019-ttg-kaw.konservasi-parigi-moutong-poso.....pdf' is not readable or an error occurred while reading.
# The PDF file '05533-kep-29-men-2012-ttg-penetapan-kawasan-konservasi-ujungnegoro.pdf' is not readable or an error occurred while reading.
# The PDF file '05e15-79-kepmen-kp-2020-ttg-teluk-berau-teluk-nusalasi-papua-barat-20-juli-2020.pdf' is not readable or an error occurred while reading.
# The PDF file '0d9fc-kepmen-nomor-94-tahun-2021.pdf' is not readable or an error occurred while reading.
# The PDF file '0f3b6-20-kepmen-kp-2020.pdf' is not readable or an error occurred while reading.
# The PDF file '16b13-kepmen-86-tahun-2020-tentang-kawasan-konservasi-sumut-edit-hm-.pdf' is not readable or an error occurred while reading.
# The PDF file '21ab9-52-kepmen-kp-2019-ttg-kaw.konservasi-morowali-morowali-utara.....pdf' is not readable or an error occurred while reading.
# The PDF file '22%20%20%20%20%20%20KEPMEN-KP%202018.pdf' is not readable or an error occurred while reading.
# The PDF file '26f49-2022kepmen-kp32.pdf' is not readable or an error occurred while reading.
# The PDF file '27224-2022kepmen-kp34.pdf' is not readable or an error occurred while reading.
# The PDF file '2b4da-77-kepmen-kp-2020-ttg-kkpd-tp-aceh-tamiang-edit-hm-3-juni-2020-otentifikasi.pdf' is not readable or an error occurred while reading.
# The PDF file '2f585-2022kepmen-kp17.pdf' is not readable or an error occurred while reading.
# The PDF file '30ad4-23-kepmen-kp-2021.pdf' is not readable or an error occurred while reading.
# The PDF file '32c53-kepmen-73-th-2021-ttg-kawasan-konservasi...aruah.pdf' is not readable or an error occurred while reading.
# The PDF file '352c3-kepmen-nomor-96-tahun-2021.pdf' is not readable or an error occurred while reading.
# The PDF file '38026-66-kepmen-kp-2020-ttg-kawasan-konservasi-pulau-mare.pdf' is not readable or an error occurred while reading.
# The PDF file '38bb7-64-kepmen-kp-2020-ttg-kawasan-konservasi-gili-ketapang.pdf' is not readable or an error occurred while reading.
# The PDF file '3b0d5-28kepmen-kp2022.pdf' is not readable or an error occurred while reading.
# The PDF file '3bf94-13-kepmen-kp-2021.pdf' is not readable or an error occurred while reading.
# The PDF file '3ca5d-2022kepmen-kp5.pdf' is not readable or an error occurred while reading.
# The PDF file '3e8cb-57-kepmen-kp-2013-ttg-kawasan-konservasi-perairan-pesisir.......pdf' is not readable or an error occurred while reading.
# The PDF file '41373-kepmen-kp-95-tahun-2021.pdf' is not readable or an error occurred while reading.
# The PDF file '4ae14-kepmen-93-tahun-2020-edit-hm-.pdf' is not readable or an error occurred while reading.
# The PDF file '4b487-2022kepmen-kp1.pdf' is not readable or an error occurred while reading.
# The PDF file '4b5ae-25-kepmen-kp-2019-ttg-kawasan-konservasi-buruway-arguni....pdf' is not readable or an error occurred while reading.
# The PDF file '4cff1-kepmen-90-tahun-2020-edit-hm-.pdf' is not readable or an error occurred while reading.
# The PDF file '4d2b0-24-kepmen-kp-2019-ttg-kawasan-koservasi-gosong-senggora....pdf' is not readable or an error occurred while reading.
# The PDF file '4db65-kepmen-91-tahun-2020-edit-hm-.pdf' is not readable or an error occurred while reading.
# The PDF file '5307b-2022kepmen-kp31.pdf' is not readable or an error occurred while reading.
# The PDF file '53ec2-50-kepmen-kp-2021.pdf' is not readable or an error occurred while reading.
# The PDF file '545ee-kepmen-kp-74-tahun-2021.pdf' is not readable or an error occurred while reading.
# The PDF file '581e3-68-kepmen-kp-2020-ttg-kawasan-konservasi-pulau-sula.pdf' is not readable or an error occurred while reading.
# The PDF file '5866b-2022kepmen-kp37.pdf' is not readable or an error occurred while reading.
# The PDF file '5e3c1-2021kepmen-kp66.pdf' is not readable or an error occurred while reading.
# The PDF file '62100-2022kepmen-kp35.pdf' is not readable or an error occurred while reading.
# The PDF file '68636-2022kepmen-kp18.pdf' is not readable or an error occurred while reading.
# The PDF file '6cfc1-kepmen-106-tahun-2021.pdf' is not readable or an error occurred while reading.
# The PDF file '720d0-22-kepmen-kp-2021.pdf' is not readable or an error occurred while reading.
# The PDF file '72ca2-kepmen-27-tahun-2021.pdf' is not readable or an error occurred while reading.
# The PDF file '7cccc-kepmen-104-tahun-2021.pdf' is not readable or an error occurred while reading.
# The PDF file '7d7d6-kepmen-89-tahun-2020-edit-hm-.pdf' is not readable or an error occurred while reading.
# The PDF file '8240b-49-kepmen-kp-2021.pdf' is not readable or an error occurred while reading.
# The PDF file '83936-53-kepmen-kp-2019-ttg-kaw-konservasi-banggai-banggai-laut.....pdf' is not readable or an error occurred while reading.
# The PDF file '86066-21-kepmen-kp-2020.pdf' is not readable or an error occurred while reading.
# The PDF file '88196-69-kepmen-kp-2020-ttg-....kkpd-kalsel-18-juni-2020.pdf' is not readable or an error occurred while reading.
# The PDF file '8c518-47-kepmen-kp-2021.pdf' is not readable or an error occurred while reading.
# The PDF file '8e6de-2022kepmen-kp2.pdf' is not readable or an error occurred while reading.
# The PDF file '90%20KEPMEN-KP%202018.pdf' is not readable or an error occurred while reading.
# The PDF file '92%20KEPMEN-KP%202018.pdf' is not readable or an error occurred while reading.
# The PDF file '92f2e-kepmen-107-tahun-2021.pdf' is not readable or an error occurred while reading.
# The PDF file '93%20KEPMEN-KP%202018.pdf' is not readable or an error occurred while reading.
# The PDF file '96239-2022kepmen-kp6.pdf' is not readable or an error occurred while reading.
# The PDF file '97a52-46-kepmen-kp-2019-ttg-kawasan-konservasi-maritim-teluk-benoa.....pdf' is not readable or an error occurred while reading.
# The PDF file 'a7198-65-kepmen-kp-2020-ttg-kawasan-konservasi-pulau-koon.pdf' is not readable or an error occurred while reading.
# The PDF file 'a930c-27kepmen-kp2022.pdf' is not readable or an error occurred while reading.
# The PDF file 'b3d92-2022kepmen-kp4.pdf' is not readable or an error occurred while reading.
# The PDF file 'b45e4-67-kepmen-kp-2020-ttg-kawasan-konservasi-pulau-rao.pdf' is not readable or an error occurred while reading.
# The PDF file 'bb5a0-2022kepmen-kp30.pdf' is not readable or an error occurred while reading.
# The PDF file 'bb637-2022kepmen-kp3.pdf' is not readable or an error occurred while reading.
# The PDF file 'bb7c1-kepmen-94-tahun-2020-tentang-kawasan-konservasi-perairan-belitung-edit-hm-.pdf' is not readable or an error occurred while reading.
# The PDF file 'c117f-kepmen-105-tahun-2021.pdf' is not readable or an error occurred while reading.
# The PDF file 'c78c5-67-kepmen-kp-2021.pdf' is not readable or an error occurred while reading.
# The PDF file 'd0235-kepmen-92-tahun-2020-edit-hm-.pdf' is not readable or an error occurred while reading.
# The PDF file 'd1821-21-kepmen-kp-2018.pdf' is not readable or an error occurred while reading.
# The PDF file 'd1cdb-kiluan.pdf' is readable.
# The PDF file 'dcbaa-76-kepmen-kp-2020-ttg-kkpd-tp-aceh-jaya-edit-hm-10-juni-2020-.pdf' is readable.
# The PDF file 'de1d6-kepmen-87-tahun-2020-tentang-kawasan-konservasi-tapteng-edit-hm-.pdf' is not readable or an error occurred while reading.
# The PDF file 'DF%20BALABALAKANG%20SULBAR.pdf' is readable.
# The PDF file 'DF%20Batang%20Segama.pdf' is readable.
# The PDF file 'DF%20Berhala%20Sumut.pdf' is readable.
# The PDF file 'DF%20Binusan%20Nunukan%20Kaltara.pdf' is readable.
# The PDF file 'DF%20KARANG%20JAHE%20REMBANG.pdf' is readable.
# The PDF file 'DF%20KARANG%20JERUK%20TEGAL.pdf' is readable.
# The PDF file 'DF%20KBT.pdf' is readable.
# The PDF file 'DF%20KK%20Babar.pdf' is readable.
# The PDF file 'DF%20KK%20Bantul%20DIY.pdf' is readable.
# The PDF file 'DF%20KK%20Bintan%20Kepri.pdf' is readable.
# The PDF file 'DF%20KK%20Buleleng%20Bali.pdf' is readable.
# The PDF file 'DF%20KK%20Karangasem%20Bali.pdf' is readable.
# The PDF file 'DF%20KK%20Kolepom%20Papua.pdf' is readable.
# The PDF file 'DF%20KK%20Pangandaran%20Jabar.pdf' is readable.
# The PDF file 'DF%20KK%20Perlang%20Ketugar%20Babel.pdf' is readable.
# The PDF file 'DF%20KK%20Pulau%20Panjang.pdf' is readable.
# The PDF file 'DF%20KK%20Teluk%20Gorontalo.pdf' is readable.
# The PDF file 'DF%20KK%20Tuing%20Babel.pdf' is readable.
# The PDF file 'DF%20KK%20Way%20Kambas.pdf' is readable.
# The PDF file 'DF%20Lipan%20Rakit.pdf' is readable.
# The PDF file 'DF%20Liukang%20Tangaya.pdf' is readable.
# The PDF file 'DF%20Liukang%20Tupabbiring.pdf' is readable.
# The PDF file 'DF%20Mahakam.pdf' is readable.
# The PDF file 'DF%20Ngambur.pdf' is readable.
# The PDF file 'DF%20PULAU%20PANJANG%20JEPARA.pdf' is readable.
# The PDF file 'Dokumen%20Final%20Anambas.pdf' is readable.
# The PDF file 'Dokumen%20Final%20Aru.pdf' is readable.
# The PDF file 'Dokumen%20Final%20Gili%20Matra.pdf' is readable.
# The PDF file 'Dokumen%20Final%20Kapoposang.pdf' is readable.
# The PDF file 'Dokumen%20Final%20Laut%20Banda.pdf' is readable.
# The PDF file 'Dokumen%20Final%20Padaido.pdf' is readable.
# The PDF file 'Dokumen%20Final%20Pieh.pdf' is readable.
# The PDF file 'Dokumen%20Final%20Raja%20Ampat.pdf' is readable.
# The PDF file 'Dokumen%20Final%20Waigeo.pdf' is readable.
# The PDF file 'Dokumen%20RPZ%20KKD%20Pulau%20Weh.pdf' is readable.
# The PDF file 'e4a95-50-kepmen-kp-2019-ttg-kaw.konservasi-donggala-buol.....pdf' is not readable or an error occurred while reading.
# The PDF file 'e63e8-78-kepmen-kp-2020-oke.pdf' is not readable or an error occurred while reading.
# The PDF file 'KEPMENKP%202009%2063%20Aru.pdf' is readable.
# The PDF file 'KEPMENKP%202014%2038%20RPZ%20Pieh.pdf' is readable.
# The PDF file 'KEPMENKP%202014%205%20Sawu.pdf' is readable.
# The PDF file 'KEPMENKP%202014%2053%20RPZ%20Anambas.pdf' is readable.
# The PDF file 'KEPMENKP%202014%2057%20RPZ%20Gili%20Matra.pdf' is readable.
# The PDF file 'KEPMENKP%202014%2058%20RPZ%20Laut%20Banda.pdf' is readable.
# The PDF file 'KEPMENKP%202014%2059%20RPZ%20Kapoposang.pdf' is readable.
# The PDF file 'KEPMENKP%202014%206%20RPZ%20Laut%20Sawu.pdf' is readable.
# The PDF file 'KEPMENKP%202014%2060%20RPZ%20Waigeo%20Sebelah%20Barat.pdf' is readable.
# The PDF file 'KEPMENKP%202014%2062%20RPZ%20Padaido.pdf' is readable.
# The PDF file 'KEPMENKP%202014%2063%20RPZ%20Raja%20Ampat.pdf' is readable.
# The PDF file 'KEPMENKP%202014%2064%20RPZ%20Aru%20Tenggara.pdf' is readable.
# The PDF file 'KEPMENKP%202015%2035%20KKPD%20Alor.pdf' is readable.
# The PDF file 'KEPMENKP%202016%205%20KKPD%20Sukabumi.pdf' is readable.
# The PDF file 'KEPMENKP%202016%206%20KKPD%20Maluku%20Tenggara.pdf' is readable.
# The PDF file 'KEPMENKP%202016%2087%20KKPD%20Berau.pdf' is readable.
# The PDF file 'KEPMENKP%202017%2052%20KKPD%20Belitung%20Timur.pdf' is readable.
# The PDF file 'KEPMENKP%202017%2053%20KKPD%20Jeen%20Womom%20Tambrauw.pdf' is readable.
# The PDF file 'KEPMENKP%202017%2054%20KKPD%20Sawo%20Lahewa%20(Sumut).pdf' is readable.
# The PDF file 'KEPMENKP%202019%2057%20KKD%20Tatoareng%20(Sulut).pdf' is readable.
# The PDF file 'KEPMENKP%202020%20102%20KKD%20Kepulauan%20Widi%20(Malut).pdf' is readable.
# The PDF file 'KEPMENKP%202020%20103%20KKD%20Kepulaun%20Guraici%20(Malut).pdf' is readable.
# The PDF file 'KEPMENKP%202020%20104%20KKD%20Makian%20Moti%20(Malut).pdf' is readable.
# The PDF file 'KEPMENKP%202020%2022%20KKPD%20Teluk%20Cempi%20(NTB).pdf' is readable.
# The PDF file 'KEPMENKP%202022%2047%20KK%20Kep%20Balabalakang%20(Sulbar).pdf' is readable.
# The PDF file 'KEPMENKP%202022%2048%20KK%20Pulau%20Berhala%20(Sumut).pdf' is readable.
# The PDF file 'KEPMENKP%202022%2049%20KK%20Mahakam.pdf' is readable.
# The PDF file 'KEPMENKP%202022%2068%20KK%20Kepulauan%20Babar%20(Maluku).pdf' is readable.
# The PDF file 'RPZ%20Aceh%20Barat%20Daya.pdf' is readable.
# The PDF file 'RPZ%20Aceh%20Besar.pdf' is readable.
# The PDF file 'RPZ%20Aceh%20Jaya.pdf' is readable.
# The PDF file 'RPZ%20Aceh%20Selatan.pdf' is readable.
# The PDF file 'RPZ%20Aceh%20Tamiang.pdf' is readable.
# The PDF file 'RPZ%20Angsana%20Kalsel.pdf' is readable.
# The PDF file 'RPZ%20Ay%20Rhun.pdf' is readable.
# The PDF file 'RPZ%20Banggai%20Dalaka.pdf' is readable.
# The PDF file 'RPZ%20Belitung%20(Babel).pdf' is readable.
# The PDF file 'RPZ%20Bontang.pdf' is readable.
# The PDF file 'RPZ%20Buano.pdf' is readable.
# The PDF file 'RPZ%20Doboto%20(Sulteng).pdf' is readable.
# The PDF file 'RPZ%20Flotim%20NTT.pdf' is readable.
# The PDF file 'RPZ%20Gili%20Banta%20(NTB).pdf' is readable.
# The PDF file 'RPZ%20Gili%20Ketapang.pdf' is readable.
# The PDF file 'RPZ%20Gita%20Nada%20(NTB).pdf' is readable.
# The PDF file 'RPZ%20Guraici%20(Malut).pdf' is readable.
# The PDF file 'RPZ%20Jeen%20Womom%20(Papua%20Barat).pdf' is readable.
# The PDF file 'RPZ%20Kaimana%20(Pabar).pdf' is readable.
# The PDF file 'RPZ%20Kayong%20Utara.pdf' is readable.
# The PDF file 'RPZ%20Kendawangan.pdf' is readable.
# The PDF file 'RPZ%20Kiluan%20(Lampung).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Kep%20Derawan%20(Kaltim).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Nusa%20Penida%20(2017).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Pulau%20Kei%20Kecil%20(Maluku).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Pulau%20Koon%20(Maluku).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Pulau-Pulau%20Batu%20(Sumut).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Raja%20Ampat%20(2019).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Sawo%20Lahewa%20(Sumut).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Selat%20Bunga%20Laut%20(Sumbar).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Tatoareng%20(Sulut).pdf' is readable.
# The PDF file 'RPZ%20KKD%20Ujungnegoro%20(Jateng).pdf' is readable.
# The PDF file 'RPZ%20KKM%20HMAS%20Perth%20(Banten).pdf' is readable.
# The PDF file 'RPZ%20Kubu%20Raya.pdf' is readable.
# The PDF file 'RPZ%20Lease.pdf' is readable.
# The PDF file 'RPZ%20Lembata%20NTT.pdf' is readable.
# The PDF file 'RPZ%20Liang%20dan%20Ngali%20(NTB).pdf' is readable.
# The PDF file 'RPZ%20Makian-Moti%20(Malut).pdf' is readable.
# The PDF file 'RPZ%20Mare%20(Malut).pdf' is readable.
# The PDF file 'RPZ%20Momparang%20(Babel).pdf' is readable.
# The PDF file 'RPZ%20Moramo%20Wawonii.pdf' is readable.
# The PDF file 'RPZ%20Morowali.pdf' is readable.
# The PDF file 'RPZ%20Paloh.pdf' is readable.
# The PDF file 'RPZ%20Pangumbahan%20(Jabar).pdf' is readable.
# The PDF file 'RPZ%20Parigi%20Muotong.pdf' is readable.
# The PDF file 'RPZ%20Pisisi%20(Aceh).pdf' is readable.
# The PDF file 'RPZ%20Pulau%20Randayan%20Bengkayang.pdf' is readable.
# The PDF file 'RPZ%20Rao-Tanjung%20Dehegila%20(Malut).pdf' is readable.
# The PDF file 'RPZ%20Selat%20Pantar%20(NTT).pdf' is readable.
# The PDF file 'RPZ%20Senggora%20-%20Kalteng.pdf' is readable.
# The PDF file 'RPZ%20Serutbar.pdf' is readable.
# The PDF file 'RPZ%20Sikka%20NTT.pdf' is readable.
# The PDF file 'RPZ%20Sula.pdf' is readable.
# The PDF file 'RPZ%20Sulat%20dan%20Lawang%20(NTB).pdf' is readable.
# The PDF file 'RPZ%20Tapanuli%20Tengah%20(Sumut).pdf' is readable.
# The PDF file 'RPZ%20Teluk%20Berau%20(Pabar).pdf' is readable.
# The PDF file 'RPZ%20Teluk%20Cempi%20(NTB).pdf' is readable.
# The PDF file 'RPZ%20Widi%20(Malut).pdf' is readable.
# The PDF file 'RZ%20KK%20Tanjung%20Palas%20Timur%20Kaltara.pdf' is readable.
# Total PDF files: 193
# Readable PDF files: 124
# Non-readable PDF files: 69

# %%
#clean up a folder by removing non-readable PDF files, 
#thus ensuring that only readable PDF files remain in the folder. 
#It uses the check_pdf_readability function to determine if a PDF is readable, and if not, it deletes the file using os.remove().

import os
import PyPDF2

def check_pdf_readability(file_path):
    try:
        with open(file_path, 'rb') as file:
            reader = PyPDF2.PdfFileReader(file)
            num_pages = reader.numPages
            return num_pages > 0  # If the number of pages is greater than 0, the file is readable
    except Exception:
        return False  # If an error occurs while reading the file, it is not readable

def delete_non_readable_pdfs(folder_path):
    pdf_files = [file for file in os.listdir(folder_path) if file.lower().endswith('.pdf')]
    num_deleted = 0

    for pdf_file in pdf_files:
        file_path = os.path.join(folder_path, pdf_file)
        is_readable = check_pdf_readability(file_path)
        
        if not is_readable:
            os.remove(file_path)
            num_deleted += 1
            print(f"The non-readable PDF file '{pdf_file}' has been deleted.")

    print(f"Total PDF files: {len(pdf_files)}")
    print(f"Non-readable PDF files deleted: {num_deleted}")

# Example usage:
folder_path = "YourDirectoryPath/Desktop/Analysis_ch1/Automated_MPAMP"
delete_non_readable_pdfs(folder_path)
# Out:
# The non-readable PDF file '02c77-48-kepmen-kp-2021.pdf' has been deleted.
# The non-readable PDF file '05455-2022kepmen-kp36.pdf' has been deleted.
# The non-readable PDF file '054f7-51-kepmen-kp-2019-ttg-kaw.konservasi-parigi-moutong-poso.....pdf' has been deleted.
# Total PDF files: 193
# Non-readable PDF files deleted: 69

# %% [markdown]
# ##to rename the pdf files in certain folder with the name in the xlx/csv in certain column
#
# import os
# import pandas as pd
#
# def rename_pdfs_with_csv(folder_path, csv_file_path):
#     pdf_files = [file for file in os.listdir(folder_path) if file.lower().endswith('.pdf')]
#     num_renamed = 0
#
#     df = pd.read_excel(csv_file_path, sheet_name="Output")
#     filename_mapping = dict(zip(df["File Name"], df["Text"]))
#
#     for pdf_file in pdf_files:
#         if pdf_file in filename_mapping:
#             file_path = os.path.join(folder_path, pdf_file)
#             new_file_name = filename_mapping[pdf_file]
#             new_file_path = os.path.join(folder_path, new_file_name + ".pdf")
#
#             # Handle conflicts by appending a unique identifier
#             count = 1
#             while os.path.exists(new_file_path):
#                 new_file_path = os.path.join(folder_path, f"{new_file_name}_{count}.pdf")
#                 count += 1
#
#             os.rename(file_path, new_file_path)
#             num_renamed += 1
#             print(f"The PDF file '{pdf_file}' has been renamed to '{os.path.basename(new_file_path)}'.")
#
#     print(f"Total PDF files: {len(pdf_files)}")
#     print(f"PDF files renamed: {num_renamed}")
#
# # Example usage:
# folder_path = r"E:\YourDirectoryPath\Desktop\Analysis_ch1\Automated_MPAMP"
# csv_file_path = r"E:\YourDirectoryPath\Desktop\Analysis_ch1\Automated_MPAMP\Excel_Output_2023-06-19 10-39-40.xlsx"
# rename_pdfs_with_csv(folder_path, csv_file_path)

# %% [markdown]
# A line-by-line explanation of the code:
#
# import os: This line imports the os module, which allows the script to use operating system-dependent functionality, like working with files and directories.
#
# Function extract_url_pdf(input_url, folder_path=os.getcwd()): This line defines the function extract_url_pdf with two parameters: input_url and folder_path. The folder_path parameter has a default value os.getcwd() (the current working directory) if no value is provided when calling the function.
#
# The subsequent lines (3 to 18) import required modules like requests, urljoin, BeautifulSoup, pandas, and datetime.
#
# url = "https://kkp.go.id/djprl/kkhl/page/2107-sk-penetapan": This line sets the URL from which the script will extract the PDF files. However, note that the URL is hard-coded, so it might not be used directly in the function.
#
# folder_location = "...": This line sets the path of the local folder where the downloaded PDF files will be stored. The path in this line is hard-coded, so you might want to change it according to your desired location.
#
# response = requests.get(url): This line sends a GET request to the specified URL and stores the response in the response variable.
#
# soup = BeautifulSoup(response.text, "html.parser"): This line creates a BeautifulSoup object soup by parsing the HTML content of the response.
#
# 13 to 36: This block of code performs the following tasks:
#
# Iterates through all anchor tags (<a>) with a hyperlink ending in '.pdf' in the parsed HTML content.
# Extracts the PDF files by downloading them using the requests.get() method.
# Appends relevant information such as link texts, URLs, and file names to lists.
# Prints the progress and the number of files extracted.
# 38 to 43: This block of code creates a pandas DataFrame df containing the extracted link texts, URLs, and file names.
#
# 45 to 50: This block of code creates an Excel file with the DataFrame df and saves it in the specified folder. The Excel file's name includes the current timestamp to ensure uniqueness.
#
# In summary, this function extracts PDF files from a given URL, downloads them to a local folder, and creates an Excel file with information about the downloaded files. Note that the function uses hard-coded values for the URL and folder location, so it may need some modifications to be more dynamic and suitable for your specific use case.
