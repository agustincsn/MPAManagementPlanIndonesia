# %% [markdown]
# Import libraries and data management plan dataset
# Change paths to your own path
# COT was a problem, I replaced 'COT' by cot in the keywords dataframe, but maybe you want to do this in the original excel file

# %%
import os
import pandas as pd
import csv

# The directory path containing the text files (all MPA management files that already converted into txt files)
directory_path = 'YourDirectoryPath/MP_ManagementActions'  # 78 MMAF MPAs


# Specify the file path of the CSV file containing keywords
keyword_file_path = 'YourDirectoryPath/keywords_python.csv'

# Specify the directory path for results
directory_result = 'YourDirectoryPath/Results/Data'

# Ensure that the directories exist
os.makedirs(directory_result, exist_ok=True)

# Load keywords from CSV file into pandas dataframe
keywords_df = pd.read_csv(keyword_file_path, delimiter=';')
keywords_df['keywords'] = keywords_df['keywords'].str.replace('COT','cot')
#display(keywords_df)

# Extract list of keywords
keywords = keywords_df.keywords.to_list()
print(keywords, '\n')

# Create a list with all texts and a list with the accompanying filenames 
text_data = []
filenames = []
for filename in os.listdir(directory_path):
    file_name = filename.replace(".txt", "")
    if filename.endswith(".txt"):
        file_path = os.path.join(directory_path, filename)
        filenames.append(file_name)
        # Read the content of each text file
        with open(file_path, 'r', encoding='utf-8') as file:
            text = file.read()
            text_data.append(text)
print(filenames)

# Dictionary with bahasa words belonging to english stressor terms
column_mapping = {
    'abrasi': 'abrasion',
    'alat tangkap yang merusak':'destructive fishing',
    'alih fungsi lahan': 'habitat loss',    
    'aliran permukaan': 'runoff',
    'badai': 'storms',    
    'bahan bangunan': 'coral mining',    
    'bahan peledak': 'blast fishing',       
    'bius': 'cyanide',
    'bleaching': 'bleaching',
    'bom':'blast fishing',    
    
    'bukaan lahan':'habitat loss',  
    'bycatch': 'bycatch',
    'by-catch': 'bycatch',    
    'climate change': 'climate change',
    'cot': 'crown of thorn',
    'crown of thorn': 'crown of thorn',
    'cuaca ekstrim': 'extreme weather',
    'cyanida': 'cyanide',    
    'deforestasi': 'deforestation',
    
    'destructive fishing': 'destructive fishing',
    'eksploitasi berlebih': 'overfishing',
    'eksploitasi karang': 'ornamental coral trade', 
    'erosi': 'erosion', 
    'eutrofikasi': 'eutrophication', 
    'eutrophication': 'eutrophication',
    'gelombang panas': 'heatwave',
    'global warming': 'global warming',
     
    'illegal fishing': 'illegal fishing',
    'jangkar': 'anchoring',
    'jaring hela': 'purse seine',
    'kenaikan suhu air laut': 'increasing SST',
    'kekeruhan': 'turbidity',
    'kompresor': 'hookah compressor',
    'letusan gunung berapi': 'volcano eruptions',
    
    'limbah cair': 'sewage discharge',
    'limbah rumah tangga': 'sewage discharge',
    'mariculture': 'mariculture',
    'minyak dan gas': 'mining (oil and gas)',
    'muroami': 'muroami',
    'overfishing': 'overfishing',
    'pemanasan global ': 'global warming',

    'pembangunan pemukiman': 'coastal development',
    'pembiusan': 'cyanide',
    'pembuangan air balast': 'ballast water',
    'pembuangan air limbah': 'sewage discharge',
    'pemutihan': 'bleaching', 
    'penambangan': 'sand mining',
    'penangkapan berlebih': 'overfishing',
    'penangkapan ikan yang berlebih': 'overfishing',
    'penangkapan ikan yang merusak': 'destructive fishing',
    'penangkapan illegal': 'illegal fishing', 
    'penangkapan merusak': 'destructive fishing',
    
    'pencurian ikan': 'illegal fishing', 
    'penebangan': 'deforestation',
    'pengambilan batu karang': 'coral mining',
    'pengambilan karang': 'coral mining',
    'pengambilan pasir': 'sand mining',
    'pengembangan pantai': 'coastal development',
    'pengembangan pesisir':  'coastal development',
    'pengikisan pantai':'abrasion',
    
    'peningkatan suhu air laut': 'increasing SST',
    'penyakit': 'disease',
    'pertambangan': 'mineral mining',
    'perubahan habitat':'habitat loss',
    'perubahan iklim': 'climate change',    
    'pestisida': 'pesticide - fertilizer',
    'planci': 'crown of thorn',
    'plastik': 'plastic',
    'potasium': 'cyanide',
    'pukat': 'purse seine',
    'pupuk': 'pesticide - fertilizer',
    'racun':'cyanide',
    
    'reklamasi': 'reclamation',
    'runoff': 'runoff',
    'run-off': 'runoff',
    'sanitasi': 'sewage discharge',
    'sedimentasi': 'sedimentation', 
    'sianida': 'cyanide',
    'tambak': 'aquaculture pond',
    'tangkap lebih': 'overfishing',
    'tangkapan sampingan': 'bycatch',
    'trawl': 'trawl',
}
# Out:
# ['abrasi', 'alat tangkap yang merusak', 'alih fungsi lahan', 'aliran permukaan', 'badai', 'bahan bangunan', 'bahan peledak', 'bius', 'bleaching', 'bom', 'bukaan lahan', 'bycatch', 'by-catch', 'climate change', 'cot', 'crown of thorn', 'cuaca ekstrim', 'cyanida', 'deforestasi', 'destructive fishing', 'eksploitasi berlebih', 'erosi', 'eutrofikasi', 'eutrophication', 'gelombang panas', 'global warming', 'illegal fishing', 'jangkar', 'jaring hela', 'kenaikan suhu air laut', 'kompresor', 'letusan gunung berapi', 'limbah cair', 'limbah rumah tangga', 'mariculture', 'minyak dan gas', 'muroami', 'overfishing', 'pemanasan global ', 'pembangunan pemukiman', 'pembiusan', 'pembuangan air balast', 'pembuangan air limbah', 'pemutihan', 'penambangan', 'penangkapan berlebih', 'penangkapan ikan yang berlebih', 'penangkapan ikan yang merusak', 'penangkapan illegal', 'penangkapan merusak', 'pencurian ikan', 'penebangan', 'pengambilan batu karang', 'pengambilan karang', 'pengambilan pasir', 'pengembangan pantai', 'pengembangan pesisir', 'pengikisan pantai', 'peningkatan suhu air laut', 'penyakit', 'pertambangan', 'perubahan habitat', 'perubahan iklim', 'pestisida', 'planci', 'plastik', 'potasium', 'pukat', 'pupuk', 'racun', 'reklamasi', 'runoff', 'run-off', 'sanitasi', 'sedimentasi', 'sianida', 'tambak', 'tangkap lebih', 'tangkapan sampingan', 'trawl']
#
# ['National_Anambas_Riau Islands_2014_ManagementActions', 'National_Aru Tenggara_Maluku_2014_ManagementActions', 'National_Banda_Maluku_2014_ManagementActions', 'National_Gili Matra_West Nusa Tenggara_2014_ManagementActions', 'National_Kapoposang_South Sulawesi_2014_ManagementActions', 'National_Padaido_Papua_2014_ManagementActions', 'National_Pieh_West Sumatra_2014_ManagementActions', 'National_Raja Ampat_West Papua_2014_ManagementActions', 'National_Sawu_East Nusa Tenggara_2014_ManagementActions', 'National_Waigeo Sebelah Barat_West Papua_2014_ManagementActions', 'Provincial_Aceh Besar_Aceh_2019_ManagementActions', 'Provincial_Aceh Jaya_Aceh_2019_ManagementActions', 'Provincial_Aceh Tamiang_Aceh_2020_ManagementActions', 'Provincial_Alor Selat Pantar_East Nusa Tenggara_2013_ManagementActions', 'Provincial_Angsana_South Kalimantan_2019_ManagementActions', 'Provincial_Ay Rhun_Maluku_2020_ManagementActions', 'Provincial_Banggai Dalaka_Central Sulawesi_2018_ManagementActions', 'Provincial_Belitung_Belitung Islands_2019_ManagementActions', 'Provincial_Bintan_Riau Islands_2021_ManagementActions', 'Provincial_Binusan Sinelak_North Kalimantan_2020_ManagementActions', 'Provincial_Bontang_East Kalimantan_2019_ManagementActions', 'Provincial_Buano_Maluku_2020_ManagementActions', 'Provincial_Derawan_East Kalimantan_2019_ManagementActions', 'Provincial_Doboto_Central Sulawesi_2021_ManagementActions', 'Provincial_Flores Timur_East Nusa Tenggara_2018_ManagementActions', 'Provincial_Gili Banta_West Nusa Tenggara_2018_ManagementActions', 'Provincial_Gili Ketapang Probolinggo_East Java_2019_ManagementActions', 'Provincial_Gili Sulat Lawang_West Nusa Tenggara_2016_ManagementActions', 'Provincial_Gili Tangkong Nanggu Sudak_West Nusa Tenggara_2016_ManagementActions', 'Provincial_Guraici_North Maluku_2020_ManagementActions', 'Provincial_HMAS Perth_Banten_2018_ManagementActions', 'Provincial_Jeen Womom_West Papua_2016_ManagementActions', 'Provincial_Kaimana_West Papua_2018_ManagementActions', 'Provincial_Kei_Maluku_2015_ManagementActions', 'Provincial_Kendawangan_West Kalimantan_2019_ManagementActions', 'Provincial_Kepulauan Balabalakang_West Sulawesi_2021_ManagementActions', 'Provincial_Keramat Bedil Temudong_West Nusa Tenggara_2016_ManagementActions', 'Provincial_Kiluan_Lampung_2014_ManagementActions', 'Provincial_Koon_Maluku_2016_ManagementActions', 'Provincial_Kubu Raya Kayong Utara_West Kalimantan_2019_ManagementActions', 'Provincial_Kubu Raya_West Kalimantan_2019_ManagementActions', 'Provincial_Lease_Maluku_2020_ManagementActions', 'Provincial_Lembata_East Nusa Tenggara_2018_ManagementActions', 'Provincial_Liang Ngali_West Nusa Tenggara_2018_ManagementActions', 'Provincial_Lipan Rakit_West Nusa Tenggara_2019_ManagementActions', 'Provincial_Liukang Tangaya_South Sulawesi_2022_ManagementActions', 'Provincial_Mahakam_East Kalimantan_2021_ManagementActions', 'Provincial_Makian Moti_North Maluku_2020_ManagementActions', 'Provincial_Mare_North Maluku_2019_ManagementActions', 'Provincial_Momparang_Bangka Belitung_2020_ManagementActions', 'Provincial_Moramo_Southeast Sulawesi_2020_ManagementActions', 'Provincial_Morowali_Central Sulawesi_2021_ManagementActions', 'Provincial_Nusa Penida_Bali_2017_ManagementActions', 'Provincial_Nusalasi van den Bosch_West Papua_2018_ManagementActions', 'Provincial_Paloh_West Kalimantan_2019_ManagementActions', 'Provincial_Pangandaran_West Java_2020_ManagementActions', 'Provincial_Pangumbahan_West Java_2014_ManagementActions', 'Provincial_Parigi Muotong_Central Sulawesi_2021_ManagementActions', 'Provincial_Pulau Berhala_North Sumatra_2021_ManagementActions', 'Provincial_Pulau Panjang_West Nusa Tenggara_2020_ManagementActions', 'Provincial_Raja Ampat_West Papua_2019_ManagementActions', 'Provincial_Randayan_West Kalimantan_2019_ManagementActions', 'Provincial_Rao Dehegila_North Maluku_2019_ManagementActions', 'Provincial_Sawo Lahewa_North Sumatra_2015_ManagementActions', 'Provincial_Selat Bunga Laut_West Sumatra_2015_Mana ...

# %%
#Total number of words per document
wordcount = []
for text in text_data:
    num_words = float(len(text.split()))
    wordcount.append(num_words)
wordcount_df = pd.DataFrame({'wordcount' : wordcount}, index = filenames)
display(wordcount_df)
# Out:
#                                                     wordcount
# National_Anambas_Riau Islands_2014_ManagementAc...     9236.0
# National_Aru Tenggara_Maluku_2014_ManagementAct...    10943.0
# National_Banda_Maluku_2014_ManagementActions           4511.0
# National_Gili Matra_West Nusa Tenggara_2014_Man...    17681.0
# National_Kapoposang_South Sulawesi_2014_Managem...    16366.0
# ...                                                       ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...    14460.0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...     8506.0
# Provincial_Ujung Negoro Roban_Central Java_2012...     8966.0
# Provincial_Weh_Aceh_2010_ManagementActions             1660.0
# Provincial_Widi_North Maluku_2020_ManagementAct...     5954.0
#
# [77 rows x 1 columns]

# %%
#Counts (TF) keywords in Bahasa
from sklearn.feature_extraction.text import CountVectorizer

count_vectorizer = CountVectorizer(vocabulary=keywords, lowercase=True, ngram_range=(1, 4))
count_matrix = count_vectorizer.fit_transform(text_data)
count_df= pd.DataFrame.sparse.from_spmatrix(count_matrix, index = filenames, columns = keywords)
display(count_df)
# Out:
#                                                     abrasi  \
# National_Anambas_Riau Islands_2014_ManagementAc...       0
# National_Aru Tenggara_Maluku_2014_ManagementAct...       0
# National_Banda_Maluku_2014_ManagementActions             0
# National_Gili Matra_West Nusa Tenggara_2014_Man...       0
# National_Kapoposang_South Sulawesi_2014_Managem...       1
# ...                                                    ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...       2
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...       0
# Provincial_Ujung Negoro Roban_Central Java_2012...       5
# Provincial_Weh_Aceh_2010_ManagementActions               0
# Provincial_Widi_North Maluku_2020_ManagementAct...       0
#
#                                                     alat tangkap yang merusak  \
# National_Anambas_Riau Islands_2014_ManagementAc...                          0
# National_Aru Tenggara_Maluku_2014_ManagementAct...                          0
# National_Banda_Maluku_2014_ManagementActions                                0
# National_Gili Matra_West Nusa Tenggara_2014_Man...                          0
# National_Kapoposang_South Sulawesi_2014_Managem...                          0
# ...                                                                       ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...                          0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...                          0
# Provincial_Ujung Negoro Roban_Central Java_2012...                          0
# Provincial_Weh_Aceh_2010_ManagementActions                                  0
# Provincial_Widi_North Maluku_2020_ManagementAct...                          0
#
#                                                     alih fungsi lahan  \
# National_Anambas_Riau Islands_2014_ManagementAc...                  0
# National_Aru Tenggara_Maluku_2014_ManagementAct...                  0
# National_Banda_Maluku_2014_ManagementActions                        0
# National_Gili Matra_West Nusa Tenggara_2014_Man...                  0
# National_Kapoposang_South Sulawesi_2014_Managem...                  0
# ...                                                               ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...                  0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...                  1
# Provincial_Ujung Negoro Roban_Central Java_2012...                  0
# Provincial_Weh_Aceh_2010_ManagementActions                          0
# Provincial_Widi_North Maluku_2020_ManagementAct...                  0
#
#                                                     aliran permukaan  badai  \
# National_Anambas_Riau Islands_2014_ManagementAc...                 0      0
# National_Aru Tenggara_Maluku_2014_ManagementAct...                 0      0
# National_Banda_Maluku_2014_ManagementActions                       0      0
# National_Gili Matra_West Nusa Tenggara_2014_Man...                 0      0
# National_Kapoposang_South Sulawesi_2014_Managem...                 0      0
# ...                                                              ...    ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...                 0      0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...                 0      0
# Provincial_Ujung Negoro Roban_Central Java_2012...                 0      0
# Provincial_Weh_Aceh_2010_ManagementActions                         0      0
# Provincial_Widi_North Maluku_2020_ManagementAct...                 0      0
#
#                                                     bahan bangunan  \
# National_Anambas_Riau Islands_2014_ManagementAc...               0
# National_Aru Tenggara_Maluku_2014_ManagementAct...               0
# National_Banda_Maluku_2014_ManagementActions                     0
# National_Gili Matra_West Nusa Tenggara_2014_Man...               0
# National_Kapoposang_South Sulawesi_2014_Managem...               0
# ...                                                            ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...               0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...               0
# Provincial_Ujung Negoro Roban_Central Java_2012...               0
# Provincial_Weh_Aceh_2010_ManagementActions                       0
# Provincial_Widi_North Maluku_2020_ManagementAct...               0
#
#                                                     bahan peledak  bius  \
# National_Anambas_Riau Islands_2014_ManagementAc...              0     0
# National_Aru Tenggara_Maluku_2014_ManagementAct...              0     0
# National_Banda_Maluku_2014_ManagementActions                    0     0
# National_Gili Matra_West Nusa Tenggara_2014_Man...              0     0
# National_Kapoposang_South Sulawesi_2014_Managem...              0     0
# ...                                                           ...   ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...              0     0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...              0     0
# Provincial_Ujung Negoro Roban_Central Java_2012...              0     0
# Provincial_Weh_Aceh_2010_ManagementActions                      0     0
# Provincial_Widi_North Maluku_2020_ManagementAct...              0     0
#
#                                                     bleaching  bom  ...  \
# National_Anambas_Riau Islands_2014_ManagementAc...          0    2  ...
# National_Aru Tenggara_Maluku_2014_ManagementAct...          0    0  ...
# National_Banda_Maluku_2014_ManagementActions                0    0  ...
# National_Gili Matra_West Nusa Tenggara_2014_Man...          0    0  ...
# National_Kapoposang_South Sulawesi_2014_Managem...          0    0  ...
# ...                                                       ...  ...  ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...          0    0  ...
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...          0    0  ...
# Provincial_Ujung Negoro Roban_Central Java_2012...          0    0  ...
# Provincial_Weh_Aceh_2010_ManagementActions                  0    0  ...
# Provincial_Widi_North Maluku_2020_ManagementAct...          0    0  ...
#
#                                                     reklamasi  runoff  \
# National_Anambas_Riau Islands_2014_ManagementAc...          0       0
# National_Aru Tenggara_Maluku_2014_ManagementAct...          0       0
# National_Banda_Maluku_2014_ManagementActions                0       0
# National_Gili Matra_West Nusa Tenggara_2014_Man...          0       0
# National_Kapoposang_South Sulawesi_2014_Managem...          0       0
# ...                                                       ...     ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...          0       0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...          0       0
# Provincial_Ujung Negoro Roban_Central Java_2012...          0       0
# Provincial_Weh_Aceh_2010_ManagementActions                  0       0
# Provincial_Widi_North Maluku_2020_ManagementAct...          0       0
#
#                                                     run-off  sanitasi  \
# National_Anambas_Riau Islands_2014_ManagementAc...        0         0
# National_Aru Tenggara_Maluku_2014_ManagementAct...        0         0
# National_Banda_Maluku_2014_ManagementActions              0         0
# National_Gili Matra_West Nusa Tenggara_2014_Man...        0         0
# National_Kapoposang_South Sulawesi_2014_Managem...        0         0
# ...                                                     ...       ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...        0         0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...        0         0
# Provincial_Ujung Negoro Roban_Central Java_2012...        0         0
# Provincial_Weh_Aceh_2010_ManagementActions                0         0
# Provincial_Widi_North Maluku_2020_ManagementAct...        0         0
#
#                                                     sedimentasi  sianida  \
# National_Anambas_Riau Islands_2014_ManagementAc...            0        1
# National_Aru Tenggara_Maluku_2014_ManagementAct...            0        0
# National_Banda_Maluku_2014_ManagementActions                  0        0
# National_Gili Matra_West Nusa Tenggara_2014_Man...            0        0
# National_Kapoposang_South Sulawesi_2014_Managem...            0        0
# ...                                                         ...      ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...            0        0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...            0        0
# Provincial_Ujung Negoro Roban_Central Java_2012...            9        0
# Provincial_Weh_Aceh_2010_ManagementActions                    0        0
# Provincial_Widi_North Maluku_2020_ManagementAct...            0        0
#
#                                                     tambak  tangkap lebih  \
# National_Anambas_Riau Islands_2014_ManagementAc...       0              2
# National_Aru Tenggara_Maluku_2014_ManagementAct...       0              0
# National_Banda_Maluku_2014_ManagementActions             0              0
# National_Gili Matra_West Nusa Tenggara_2014_Man...       0              0
# National_Kapoposang_South Sulawesi_2014_Managem...       0              0
# ...                                                    ...            ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...       0              2
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...       0              0
# Provincial_Ujung Negoro Roban_Central Java_2012...       0              0
# Provincial_Weh_Aceh_2010_ManagementActions               0              0
# Provincial_Widi_North Maluku_2020_ManagementAct...       0              0
#
#                                                     tangkapan sampingan  trawl
# National_Anambas_Riau Islands_2014_ManagementAc...                    0      0
# National_Aru Tenggara_Maluku_2014_ManagementAct...                    0      0
# National_Banda_Maluku_2014_ManagementActions                          0      0
# National_Gili Matra_West Nusa Tenggara_2014_Man...                    0      0
# National_Kapoposang_South Sulawesi_2014_Managem...                    0      0
# ...                                                                 ...    ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...                    0      0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...                    0      0
# Provincial_Ujung Negoro Roban_Central Java_2012...                    0      0
# Provincial_Weh_Aceh_2010_ManagementActions                            0      0
# Provincial_Widi_North Maluku_2020_ManagementAct...                    0      0
#
# [77 rows x 80 columns]

# %%
#Counts (TF) keywords in English
# Rename the columns as per column_mapping
count_eng_df = count_df.rename(columns=column_mapping)
# Sum columns with the same name
count_eng_df = count_eng_df.T.groupby(count_eng_df.columns).sum().T
keywords_eng = count_eng_df.columns.to_list()
print(keywords_eng)
display(count_eng_df)
# Out:
# ['abrasion', 'anchoring', 'aquaculture pond', 'ballast water', 'bleaching', 'blast fishing', 'bycatch', 'climate change', 'coastal development', 'coral mining', 'crown of thorn', 'cyanide', 'deforestation', 'destructive fishing', 'disease', 'erosion', 'eutrophication', 'extreme weather', 'global warming', 'habitat loss', 'heatwave', 'hookah compressor', 'illegal fishing', 'increasing SST', 'mariculture', 'mineral mining', 'mining (oil and gas)', 'muroami', 'overfishing', 'pesticide - fertilizer', 'plastic', 'purse seine', 'reclamation', 'runoff', 'sand mining', 'sedimentation', 'sewage discharge', 'storms', 'trawl', 'volcano eruptions']
#                                                     abrasion  anchoring  \
# National_Anambas_Riau Islands_2014_ManagementAc...         0          1
# National_Aru Tenggara_Maluku_2014_ManagementAct...         0          0
# National_Banda_Maluku_2014_ManagementActions               0          0
# National_Gili Matra_West Nusa Tenggara_2014_Man...         0          1
# National_Kapoposang_South Sulawesi_2014_Managem...         1          0
# ...                                                      ...        ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...         2          0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...         0          0
# Provincial_Ujung Negoro Roban_Central Java_2012...         5          0
# Provincial_Weh_Aceh_2010_ManagementActions                 0          0
# Provincial_Widi_North Maluku_2020_ManagementAct...         0          0
#
#                                                     aquaculture pond  \
# National_Anambas_Riau Islands_2014_ManagementAc...                 0
# National_Aru Tenggara_Maluku_2014_ManagementAct...                 0
# National_Banda_Maluku_2014_ManagementActions                       0
# National_Gili Matra_West Nusa Tenggara_2014_Man...                 0
# National_Kapoposang_South Sulawesi_2014_Managem...                 0
# ...                                                              ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...                 0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...                 0
# Provincial_Ujung Negoro Roban_Central Java_2012...                 0
# Provincial_Weh_Aceh_2010_ManagementActions                         0
# Provincial_Widi_North Maluku_2020_ManagementAct...                 0
#
#                                                     ballast water  bleaching  \
# National_Anambas_Riau Islands_2014_ManagementAc...              0          0
# National_Aru Tenggara_Maluku_2014_ManagementAct...              0          0
# National_Banda_Maluku_2014_ManagementActions                    0          0
# National_Gili Matra_West Nusa Tenggara_2014_Man...              0          0
# National_Kapoposang_South Sulawesi_2014_Managem...              0          0
# ...                                                           ...        ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...              0          0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...              0          0
# Provincial_Ujung Negoro Roban_Central Java_2012...              0          0
# Provincial_Weh_Aceh_2010_ManagementActions                      0          0
# Provincial_Widi_North Maluku_2020_ManagementAct...              0          0
#
#                                                     blast fishing  bycatch  \
# National_Anambas_Riau Islands_2014_ManagementAc...        2        0
# National_Aru Tenggara_Maluku_2014_ManagementAct...        0        0
# National_Banda_Maluku_2014_ManagementActions              0        0
# National_Gili Matra_West Nusa Tenggara_2014_Man...        0        0
# National_Kapoposang_South Sulawesi_2014_Managem...        0        0
# ...                                                     ...      ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...        0        0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...        0        0
# Provincial_Ujung Negoro Roban_Central Java_2012...        0        0
# Provincial_Weh_Aceh_2010_ManagementActions                0        0
# Provincial_Widi_North Maluku_2020_ManagementAct...        0        0
#
#                                                     climate change  \
# National_Anambas_Riau Islands_2014_ManagementAc...               0
# National_Aru Tenggara_Maluku_2014_ManagementAct...               0
# National_Banda_Maluku_2014_ManagementActions                     0
# National_Gili Matra_West Nusa Tenggara_2014_Man...              41
# National_Kapoposang_South Sulawesi_2014_Managem...               0
# ...                                                            ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...               2
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...               0
# Provincial_Ujung Negoro Roban_Central Java_2012...               0
# Provincial_Weh_Aceh_2010_ManagementActions                       0
# Provincial_Widi_North Maluku_2020_ManagementAct...               0
#
#                                                     coastal development  \
# National_Anambas_Riau Islands_2014_ManagementAc...                    0
# National_Aru Tenggara_Maluku_2014_ManagementAct...                    0
# National_Banda_Maluku_2014_ManagementActions                          0
# National_Gili Matra_West Nusa Tenggara_2014_Man...                    0
# National_Kapoposang_South Sulawesi_2014_Managem...                    0
# ...                                                                 ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...                    0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...                    0
# Provincial_Ujung Negoro Roban_Central Java_2012...                    0
# Provincial_Weh_Aceh_2010_ManagementActions                            0
# Provincial_Widi_North Maluku_2020_ManagementAct...                    0
#
#                                                     coral mining  ...  \
# National_Anambas_Riau Islands_2014_ManagementAc...             0  ...
# National_Aru Tenggara_Maluku_2014_ManagementAct...             0  ...
# National_Banda_Maluku_2014_ManagementActions                   0  ...
# National_Gili Matra_West Nusa Tenggara_2014_Man...             0  ...
# National_Kapoposang_South Sulawesi_2014_Managem...             0  ...
# ...                                                          ...  ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...             0  ...
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...             0  ...
# Provincial_Ujung Negoro Roban_Central Java_2012...             0  ...
# Provincial_Weh_Aceh_2010_ManagementActions                     0  ...
# Provincial_Widi_North Maluku_2020_ManagementAct...             0  ...
#
#                                                     plastic  purse seine  \
# National_Anambas_Riau Islands_2014_ManagementAc...        0            0
# National_Aru Tenggara_Maluku_2014_ManagementAct...        0            0
# National_Banda_Maluku_2014_ManagementActions              0            0
# National_Gili Matra_West Nusa Tenggara_2014_Man...        0            0
# National_Kapoposang_South Sulawesi_2014_Managem...        0            0
# ...                                                     ...          ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...        0            0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...        0            0
# Provincial_Ujung Negoro Roban_Central Java_2012...        0            0
# Provincial_Weh_Aceh_2010_ManagementActions                0            0
# Provincial_Widi_North Maluku_2020_ManagementAct...        0            0
#
#                                                     reclamation  runoff  \
# National_Anambas_Riau Islands_2014_ManagementAc...            0       0
# National_Aru Tenggara_Maluku_2014_ManagementAct...            0       0
# National_Banda_Maluku_2014_ManagementActions                  0       0
# National_Gili Matra_West Nusa Tenggara_2014_Man...            0       0
# National_Kapoposang_South Sulawesi_2014_Managem...            0       0
# ...                                                         ...     ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...            0       0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...            0       0
# Provincial_Ujung Negoro Roban_Central Java_2012...            0       0
# Provincial_Weh_Aceh_2010_ManagementActions                    0       0
# Provincial_Widi_North Maluku_2020_ManagementAct...            0       0
#
#                                                     sand mining  \
# National_Anambas_Riau Islands_2014_ManagementAc...            0
# National_Aru Tenggara_Maluku_2014_ManagementAct...            0
# National_Banda_Maluku_2014_ManagementActions                  0
# National_Gili Matra_West Nusa Tenggara_2014_Man...            0
# National_Kapoposang_South Sulawesi_2014_Managem...            0
# ...                                                         ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...            0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...            0
# Provincial_Ujung Negoro Roban_Central Java_2012...            0
# Provincial_Weh_Aceh_2010_ManagementActions                    0
# Provincial_Widi_North Maluku_2020_ManagementAct...            0
#
#                                                     sedimentation  \
# National_Anambas_Riau Islands_2014_ManagementAc...              0
# National_Aru Tenggara_Maluku_2014_ManagementAct...              0
# National_Banda_Maluku_2014_ManagementActions                    0
# National_Gili Matra_West Nusa Tenggara_2014_Man...              0
# National_Kapoposang_South Sulawesi_2014_Managem...              0
# ...                                                           ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...              0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...              0
# Provincial_Ujung Negoro Roban_Central Java_2012...              9
# Provincial_Weh_Aceh_2010_ManagementActions                      0
# Provincial_Widi_North Maluku_2020_ManagementAct...              0
#
#                                                     sewage discharge  storms  \
# National_Anambas_Riau Islands_2014_ManagementAc...                 0       0
# National_Aru Tenggara_Maluku_2014_ManagementAct...                 0       0
# National_Banda_Maluku_2014_ManagementActions                       0       0
# National_Gili Matra_West Nusa Tenggara_2014_Man...                 0       0
# National_Kapoposang_South Sulawesi_2014_Managem...                 0       0
# ...                                                              ...     ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...                 0       0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...                 0       0
# Provincial_Ujung Negoro Roban_Central Java_2012...                 0       0
# Provincial_Weh_Aceh_2010_ManagementActions                         0       0
# Provincial_Widi_North Maluku_2020_ManagementAct...                 0       0
#
#                                                     trawl  volcano eruptions
# National_Anambas_Riau Islands_2014_ManagementAc...      0                  0
# National_Aru Tenggara_Maluku_2014_ManagementAct...      0                  0
# National_Banda_Maluku_2014_ManagementActions            0                  1
# National_Gili Matra_West Nusa Tenggara_2014_Man...      0                  0
# National_Kapoposang_South Sulawesi_2014_Managem...      0                  0
# ...                                                   ...                ...
# Provincial_Tatoareng_North Sulawesi_2019_Manage...      0                  0
# Provincial_Teluk Cempi_West Nusa Tenggara_2018_...      0                  0
# Provincial_Ujung Negoro Roban_Central Java_2012...      0                  0
# Provincial_Weh_Aceh_2010_ManagementActions              0                  0
# Provincial_Widi_North Maluku_2020_ManagementAct...      0                  0
#
# [77 rows x 40 columns]

# %%
len(keywords_eng)
# Out:
# 40

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import re  # Import the re module for regular expressions

# Extracting the year from filenames
years = []
for filename in filenames:
    year_match = re.search(r'_(\d{4})_', filename)  # Look for a 4-digit year preceded by an underscore at the end
    if year_match:
        year = year_match.group(1)
    else:
        year = 'Unknown'
    years.append(year)
                
# Create a DataFrame for the extracted years
years_df = pd.DataFrame({'Year': years}, index=filenames)

# Combine the DataFrames
combined_df = pd.concat([wordcount_df, years_df, count_eng_df], axis=1)

# Create a new 'File Name' column with the filenames
combined_df.insert(0, 'File Name', combined_df.index)

# Reset the index to avoid confusion
combined_df.reset_index(drop=True, inplace=True)

# Specify your desired file path and name for the Excel file
excel_file_path = 'YourDirectoryPath/Results/Data/Absolute_keyword_count_Actions.xlsx'  
combined_df.to_excel(excel_file_path, engine='openpyxl', index=False)  

print("DataFrame saved to Excel successfully!")
# Out:
# DataFrame saved to Excel successfully!

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Read the Excel file into a DataFrame
df = pd.read_excel('YourDirectoryPath/Results/Data/Absolute_keyword_count_Actions.xlsx')

# Fill NaN values with 0 in all numeric columns
df.fillna(0, inplace=True)

# Manually specify subcategories
categories = {
    'Other': ['coral mining', 'mining (oil and gas)', 'disease',
              'crown of thorn', 'volcano eruptions', 'mariculture',
              'ballast water'],
    'Climate Change': ['climate change', 'bleaching', 'storms', 'global warming', 'increasing SST',
                       'extreme weather', 'heatwave'],
    'Land-based': ['sedimentation', 'abrasion', 'deforestation', 'aquaculture pond',
                   'erosion', 'sewage discharge', 'habitat loss', 'pesticide - fertilizer', 
                   'reclamation', 'eutrophication', 'coastal development', 
                   'runoff', 'plastic', 'mineral mining', 'sand mining'],
    'Fishing Activities': ['blast fishing', 'cyanide', 'anchoring', 'destructive fishing', 'purse seine',
                          'hookah compressor', 'trawl', 'overfishing', 'illegal fishing', 
                          'bycatch', 'muroami'],
}

# Calculate document count per column (non-zero entries)
document_count_per_column = df.astype(bool).sum()

# Exclude columns that are not stressors (e.g., 'File Name', 'Year', 'wordcount')
exclude_columns = ['File Name', 'Year', 'wordcount']
document_count_per_column = document_count_per_column.drop(exclude_columns, errors='ignore')

# Convert counts to a dictionary for easier access
document_count_dict = document_count_per_column.to_dict()

# Print document counts per subcategory
for category, subcategories in categories.items():
    print(f"{category}:")
    for subcategory in subcategories:
        count = document_count_dict.get(subcategory, 0)
        print(f"  {subcategory}: {count}")
# Out:
# Other:
#   coral mining: 3
#   mining (oil and gas): 9
#   disease: 12
#   crown of thorn: 1
#   volcano eruptions: 2
#   mariculture: 0
#   ballast water: 0
# Climate Change:
#   climate change: 28
#   bleaching: 13
#   storms: 5
#   global warming: 0
#   increasing SST: 0
#   extreme weather: 1
#   heatwave: 0
# Land-based:
#   sedimentation: 4
#   abrasion: 13
#   deforestation: 3
#   aquaculture pond: 1
#   erosion: 6
#   sewage discharge: 4
#   habitat loss: 6
#   pesticide - fertilizer: 1
#   reclamation: 2
#   eutrophication: 2
#   coastal development: 0
#   runoff: 0
#   plastic: 2
#   mineral mining: 14
#   sand mining: 10
# Fishing Activities:
#   blast fishing: 16
#   cyanide: 9
#   anchoring: 6
#   destructive fishing: 15
#   purse seine: 0
#   hookah compressor: 8
#   trawl: 2
#   overfishing: 9
#   illegal fishing: 8
#   bycatch: 3
#   muroami: 0

# %%
import matplotlib.pyplot as plt

# Collect all subcategories and their document counts in a list
all_subcategories = []
all_counts = []

# Populate subcategories and counts from the dictionary
for category, subcategories in categories.items():
    for subcategory in subcategories:
        count = document_count_dict.get(subcategory, 0)
        all_subcategories.append(subcategory)
        all_counts.append(count)

# Sort the subcategories by their counts in ascending order
sorted_subcategories, sorted_counts = zip(*sorted(zip(all_subcategories, all_counts), key=lambda x: x[1]))

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
ax.barh(sorted_subcategories, sorted_counts, color='skyblue')

# Add labels and title
ax.set_xlabel('Document Count')
ax.set_title('Document Count by Stressor Subcategory (Ascending Order)')
plt.tight_layout()

# Show the plot
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Read the Excel file into a DataFrame
df = pd.read_excel('YourDirectoryPath/Results/Data/Absolute_keyword_count_Actions.xlsx')

# Fill NaN values with 0 in all numeric columns
df.fillna(0, inplace=True)

# Manually specify subcategories
categories = {
    'Other': ['coral mining',
              #'mining (oil and gas)', 'disease',
              #'crown of thorn', 'volcano eruptions', 'mariculture',
              'ballast water'],
   # 'Climate Change': ['climate change', 'bleaching', 'storms', 'global warming', 'increasing SST',
    #                   'extreme weather', 'heatwave'],
    #'Land-based': ['sedimentation', 'abrasion', 'deforestation', 'aquaculture pond',
     #              'erosion', 'sewage discharge', 'habitat loss', 'pesticide - fertilizer', 
      #             'reclamation', 'eutrophication', 'coastal development', 
       #            'runoff', 'plastic', 'mineral mining', 'sand mining'],
    #'Fishing Activities': ['blast fishing', 'cyanide', 'anchoring', 'destructive fishing', 'purse seine',
       #                   'hookah compressor', 'trawl', 'overfishing', 'illegal fishing', 
      #                    'bycatch', 'muroami'],
}

# Create a dictionary to store documents for each stressor
documents_per_stressor = {}

# Iterate through each subcategory to find documents
for category, subcategories in categories.items():
    for subcategory in subcategories:
        # Find documents that mention the stressor
        documents = df[df[subcategory] > 0]['File Name'].tolist()  # Assuming 'File Name' column contains document names
        documents_per_stressor[subcategory] = documents

# Print out the documents mentioning each stressor
for subcategory, documents in documents_per_stressor.items():
    print(f"{subcategory}: {documents}")
# Out:
# coral mining: ['National_Sawu_East Nusa Tenggara_2014_ManagementActions', 'Provincial_Angsana_South Kalimantan_2019_ManagementActions', 'Provincial_Raja Ampat_West Papua_2019_ManagementActions']
# ballast water: []
